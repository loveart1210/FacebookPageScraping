# %%
import json
import os
from typing import List, Dict
import google.generativeai as genai
from datetime import datetime, timedelta
from collections import deque
import time

# %%
# Cấu hình API key cho Gemini
genai.configure(api_key='AIzaSyAY76hftIXFHe9zxXPR00FYePmoZQ1TLZg')
model = genai.GenerativeModel('gemini-2.0-flash')

# %%
class RateLimiter:
    def __init__(self, max_requests=15, time_window=70, cooldown=70):
        self.max_requests = max_requests
        self.time_window = time_window
        self.cooldown = cooldown
        self.requests = deque()
    
    def wait_if_needed(self):
        now = datetime.now()
        
        # Xóa các request cũ hơn time_window
        while self.requests and (now - self.requests[0]).total_seconds() > self.time_window:
            self.requests.popleft()
        
        # Nếu đã đạt giới hạn request
        if len(self.requests) >= self.max_requests:
            oldest_request = self.requests[0]
            wait_time = self.time_window - (now - oldest_request).total_seconds()
            
            if wait_time > 0:
                print(f"\nĐã đạt giới hạn {self.max_requests} requests trong {self.time_window}s.")
                print(f"Nghỉ {self.cooldown}s trước khi tiếp tục...")
                time.sleep(self.cooldown)
                self.requests.clear()
                
        self.requests.append(now)

# %%
def detect_abbreviations(text: str) -> List[str]:
    """
    Gọi Gemini API để nhận diện các từ viết tắt trong văn bản.
    Trả về danh sách các từ viết tắt, loại bỏ trùng lặp.
    """
    max_retries = 5
    
    for attempt in range(max_retries):
        try:
            prompt = f"""
            Phân tích văn bản tiếng Việt sau và liệt kê các từ viết tắt hoặc ký hiệu không rõ ràng về ngữ nghĩa (ví dụ: từ rút gọn, viết tắt phổ biến như 'ad', 'ib', 'tt', 'rep', ...). 
            Chỉ trả về danh sách các từ viết tắt, không giải thích. Nếu không có từ viết tắt, trả về danh sách rỗng.
            Văn bản: {text}
            """
            response = model.generate_content(prompt)
            abbreviations = response.text.strip().split("\n")
            # Loại bỏ các dòng trống và trùng lặp
            abbreviations = list(set([abbr.strip() for abbr in abbreviations if abbr.strip()]))
            return abbreviations if abbreviations else []
            
        except Exception as e:
            if attempt < max_retries - 1:
                print(f"Lỗi trong lần thử {attempt + 1}, thử lại...")
                time.sleep(5)
            else:
                print(f"Lỗi khi gọi API cho văn bản: {text[:50]}... - {e}")
                return []

# %%
def process_json_file(input_file: str, output_file: str):
    """
    Đọc file JSON, xử lý từng post để tìm từ viết tắt và lưu kết quả.
    """
    # Khởi tạo rate limiter
    rate_limiter = RateLimiter(max_requests=15, time_window=60, cooldown=10)
    
    try:
        # Đọc file JSON đầu vào
        with open(input_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        results = []
        total_posts = len(data)
        
        for idx, post in enumerate(data, 1):
            # Kiểm tra rate limit
            rate_limiter.wait_if_needed()
            
            post_text = str(post.get("Post Text", ""))
            if not post_text:
                continue
                
            print(f"\nXử lý {idx}/{total_posts}: {post_text[:100]}...")
            
            # Tìm từ viết tắt
            abbreviations = detect_abbreviations(post_text)
            print(f"Xử lý hoàn tất [{post_text[:50]}...] - Tìm thấy: {abbreviations}")
            
            # Tạo kết quả cho post
            result = {
                "index": post.get("index", ""),
                "Page URL": post.get("Page URL", ""),
                "Page Name": post.get("Page Name", ""),
                "Post URL": post.get("Post URL", ""),
                "Post Text": post_text,
                "Abbreviations": abbreviations
            }
            results.append(result)
            
        # Lưu kết quả vào file JSON
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
            
        print(f"\nĐã xử lý xong {total_posts} posts và lưu kết quả vào {output_file}")
        
    except Exception as e:
        print(f"Lỗi khi xử lý file: {e}")

# %%
if __name__ == "__main__":
    # Đường dẫn file đầu vào và đầu ra
    input_file = "../../Facebook Page Posts Scraping/Clean Data/output/Confessions of HNMU.json"
    
    # Tạo thư mục output trong thư mục hiện tại
    output_dir = "output"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Đường dẫn file kết quả trong thư mục output
    output_file = os.path.join(output_dir, "abbreviations_result.json")
    
    print(f"Bắt đầu xử lý file: {input_file}")
    print(f"Kết quả sẽ được lưu vào: {output_file}")
    
    process_json_file(input_file, output_file)
# Out:
# Bắt đầu xử lý file: ../../Facebook Page Posts Scraping/Clean Data/output/Confessions of HNMU.json
# Kết quả sẽ được lưu vào: output\abbreviations_result.json
#
# Xử lý 1/2641: ['8149: Mình được các cô ở phòng CTQLHSSV nhắc là báo với các bạn dù đã, sắp và chưa tốt nghiệp thì ...
# Xử lý hoàn tất [['8149: Mình được các cô ở phòng CTQLHSSV nhắc là ...] - Tìm thấy: ["['CTQLHSSV', 'NĐ']"]
#
# Xử lý 2/2641: ['8147: Mn ơi cho e hỏi bao giờ trường xét vb2 ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8147: Mn ơi cho e hỏi bao giờ trường xét vb2 ạ']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Xử lý hoàn tất [['8147: Mn ơi cho e hỏi bao giờ trường xét vb2 ạ']...] - Tìm thấy: []
#
# Xử lý 3/2641: ['8148: bao h có ds hb dự kiến v ạ ___________________ #hnmuhoidap #hnmucfs']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Xử lý hoàn tất [['8148: bao h có ds hb dự kiến v ạ _______________...] - Tìm thấy: ["['ds', 'hb', 'v', 'ạ']"]
#
# Xử lý 4/2641: ['8145: Eeeeee.... trường có thật sự công bằng không vậy. Chấm điểm các trung đội kiểu gì vậy???????...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Xử lý hoàn tất [['8145: Eeeeee.... trường có thật sự công bằng khô...] - Tìm thấy: ["['ng', 'đc', 'vch', 'Kk', 'hs', 'oke']"]
#
# Xử lý 5/2641: ['8146: Các bạn sinh viên khoa S đang đòi trợ cấp ___________________ #hnmufeedback #hnmucfs']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8146: Các bạn sinh viên khoa S đang đòi trợ cấp ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Xử lý hoàn tất [['8146: Các bạn sinh viên khoa S đang đòi trợ cấp ...] - Tìm thấy: []
#
# Xử lý 6/2641: ['8144: Em chào các anh chị ạ. Các anh chị học ngành ngôn ngữ Trung và Anh có thể cho em xin review ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8144: Em chào các anh chị ạ. Các anh chị học ngà... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
# Xử lý hoàn tất [['8144: Em chào các anh chị ạ. Các anh chị học ngà...] - Tìm thấy: []
#
# Xử lý 7/2641: ['8142: E tìm 2 bạn nữ ở trọ ạ, chuyển vào từ t8, gần cs1 ạ. Hoặc có bạn nào cần tìm người ở ghép th...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8142: E tìm 2 bạn nữ ở trọ ạ, chuyển vào từ t8, ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Xử lý hoàn tất [['8142: E tìm 2 bạn nữ ở trọ ạ, chuyển vào từ t8, ...] - Tìm thấy: []
#
# Xử lý 8/2641: ['8143: có b nào đang cần tìm trọ hoặc tìm người ở ghép ko ạ có thể tìm trọ và ở với mk được ko, hiệ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8143: có b nào đang cần tìm trọ hoặc tìm người ở... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Xử lý hoàn tất [['8143: có b nào đang cần tìm trọ hoặc tìm người ở...] - Tìm thấy: []
#
# Xử lý 9/2641: ['8137: Đi quân sự dc mang thảm yoga không mn?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8137: Đi quân sự dc mang thảm yoga không mn?']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Xử lý hoàn tất [['8137: Đi quân sự dc mang thảm yoga không mn?']...] - Tìm thấy: []
#
# Xử lý 10/2641: ['8138: Điểm qp 1,2 là làm bài kiểm tra trên khu qsu ạ?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8138: Điểm qp 1,2 là làm bài kiểm tra trên khu q... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Xử lý hoàn tất [['8138: Điểm qp 1,2 là làm bài kiểm tra trên khu q...] - Tìm thấy: []
#
# Xử lý 11/2641: ['8139: Cho e hỏi bao giờ trường mình mới xét hb v ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8139: Cho e hỏi bao giờ trường mình mới xét hb v... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Xử lý hoàn tất [['8139: Cho e hỏi bao giờ trường mình mới xét hb v...] - Tìm thấy: []
#
# Xử lý 12/2641: ['8140: Mn ơi cho e hỏi ngoại ngữ e đki học tiếng trung thì cc ngoại ngữ đầu ra của e phải là tiếng ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8140: Mn ơi cho e hỏi ngoại ngữ e đki học tiếng ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Xử lý hoàn tất [['8140: Mn ơi cho e hỏi ngoại ngữ e đki học tiếng ...] - Tìm thấy: []
#
# Xử lý 13/2641: ['8141: Lms để qua môn gdtc ạ cụ thể là điền kinh ___________________ 8137 không ai kiểm tra đồ các ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8141: Lms để qua môn gdtc ạ cụ thể là điền kinh ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Xử lý hoàn tất [['8141: Lms để qua môn gdtc ạ cụ thể là điền kinh ...] - Tìm thấy: []
#
# Xử lý 14/2641: ['8136: Vì trường pr lắm quá nên mỗi ngày tao sẽ up 1 cfs nội dung chỉ ghi #hnmufeedback để các em v...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8136: Vì trường pr lắm quá nên mỗi ngày tao sẽ u... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# Xử lý hoàn tất [['8136: Vì trường pr lắm quá nên mỗi ngày tao sẽ u...] - Tìm thấy: []
#
# Xử lý 15/2641: ['8135: Tìm roommate ở ghép cách cs3 400m, vskk, full chi phí khoảng 1tr3/người ( ở 2 ), ai có nhu c...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8135: Tìm roommate ở ghép cách cs3 400m, vskk, f... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Xử lý hoàn tất [['8135: Tìm roommate ở ghép cách cs3 400m, vskk, f...] - Tìm thấy: []
#
# Xử lý 16/2641: ['8126: Mọi người ơi cho em hỏi thể dục nên đăng kí môn gì ạ (trừ mấy môn bóng với cầu ra vì em chơi...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8126: Mọi người ơi cho em hỏi thể dục nên đăng k... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Xử lý hoàn tất [['8126: Mọi người ơi cho em hỏi thể dục nên đăng k...] - Tìm thấy: []
#
# Xử lý 17/2641: ['8127: Cho em hỏi đi quân sự thì vali để ở trong phòng hay là có kho vali riêng để để vào vậy ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8127: Cho em hỏi đi quân sự thì vali để ở trong ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Xử lý hoàn tất [['8127: Cho em hỏi đi quân sự thì vali để ở trong ...] - Tìm thấy: []
#
# Xử lý 18/2641: ['8128: Cho mình hỏi là mk học từ tháng 9 đến tháng 6 là 10 tháng mà sao chỉ đc nhận trợ cấp 8 tháng...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8128: Cho mình hỏi là mk học từ tháng 9 đến thán... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Xử lý hoàn tất [['8128: Cho mình hỏi là mk học từ tháng 9 đến thán...] - Tìm thấy: []
#
# Xử lý 19/2641: ['8129: Cho em hỏi là chủ nhật có được về không ạ, nếu muốn về chủ nhật có cần nộp đơn gì không ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8129: Cho em hỏi là chủ nhật có được về không ạ,... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# Xử lý hoàn tất [['8129: Cho em hỏi là chủ nhật có được về không ạ,...] - Tìm thấy: []
#
# Xử lý 20/2641: ['8130: Em 2k7 định xét nguyện vọng gdth ở trường. Mọi người cho em xin review thật về trường được k...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8130: Em 2k7 định xét nguyện vọng gdth ở trường.... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Xử lý hoàn tất [['8130: Em 2k7 định xét nguyện vọng gdth ở trường....] - Tìm thấy: []
#
# Xử lý 21/2641: ['8131: Trường mình có kết quả phúc khảo k24 chưa ạ???']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8131: Trường mình có kết quả phúc khảo k24 chưa ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Xử lý hoàn tất [['8131: Trường mình có kết quả phúc khảo k24 chưa ...] - Tìm thấy: []
#
# Xử lý 22/2641: ['8132: Có kết quả phúc khảo k24 chưa ạ??']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8132: Có kết quả phúc khảo k24 chưa ạ??']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# Xử lý hoàn tất [['8132: Có kết quả phúc khảo k24 chưa ạ??']...] - Tìm thấy: []
#
# Xử lý 23/2641: ['8133: Cho mình hỏi điều kiện đầu ra TOEIC của K22 là 4kn hay 2kn vậy ạ?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8133: Cho mình hỏi điều kiện đầu ra TOEIC của K2... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Xử lý hoàn tất [['8133: Cho mình hỏi điều kiện đầu ra TOEIC của K2...] - Tìm thấy: []
#
# Xử lý 24/2641: ['8134: k ac nào giải đáp giúp chúng e về việc đki học song ngành đc ạ ? ___________________ 8127 để...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8134: k ac nào giải đáp giúp chúng e về việc đki... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Xử lý hoàn tất [['8134: k ac nào giải đáp giúp chúng e về việc đki...] - Tìm thấy: []
#
# Xử lý 25/2641: ['8123: Pass đồng phục thể chất size L nhee']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8123: Pass đồng phục thể chất size L nhee']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# Xử lý hoàn tất [['8123: Pass đồng phục thể chất size L nhee']...] - Tìm thấy: []
#
# Xử lý 26/2641: ['8124: mn ơi mình pass dptc size xl']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8124: mn ơi mình pass dptc size xl']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Xử lý hoàn tất [['8124: mn ơi mình pass dptc size xl']...] - Tìm thấy: []
#
# Xử lý 27/2641: ['8125: PASS ĐỒNG PHỤC THỂ CHẤT SIZE XL 100K ___________________ #hnmupass #hnmucfs']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8125: PASS ĐỒNG PHỤC THỂ CHẤT SIZE XL 100K _____... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Xử lý hoàn tất [['8125: PASS ĐỒNG PHỤC THỂ CHẤT SIZE XL 100K _____...] - Tìm thấy: []
#
# Xử lý 28/2641: ['8122: Người bạn họ Trương tên L đếm vội cũng phải 6 cô người yêu nhờ ___________________ #hnmuvar ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8122: Người bạn họ Trương tên L đếm vội cũng phả... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Xử lý hoàn tất [['8122: Người bạn họ Trương tên L đếm vội cũng phả...] - Tìm thấy: []
#
# Xử lý 29/2641: ['8121: Mai Em co ranh khong Di lam xong ay Lgii Lam xong cung toi om roiii Toi nhung co den Minh ch...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8121: Mai Em co ranh khong Di lam xong ay Lgii L... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Xử lý hoàn tất [['8121: Mai Em co ranh khong Di lam xong ay Lgii L...] - Tìm thấy: []
#
# Xử lý 30/2641: ['8117: tìm bạn nào pass đptc size L ạ ___________________ #hnmupass #hnmucfs']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8117: tìm bạn nào pass đptc size L ạ ___________... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Xử lý hoàn tất [['8117: tìm bạn nào pass đptc size L ạ ___________...] - Tìm thấy: []
#
# Xử lý 31/2641: ['8118: Mình là nam có nhu cầu ở ghép, bạn nào là nam đang ở trọ 1 mình hoặc cũng đang tìm người ở g...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8118: Mình là nam có nhu cầu ở ghép, bạn nào là ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Xử lý hoàn tất [['8118: Mình là nam có nhu cầu ở ghép, bạn nào là ...] - Tìm thấy: []
#
# Xử lý 32/2641: ['8119: Mình là nữ đang tìm trọ ạ. Có bạn nào cần người ở ghép để lại cmt, mình sẽ ib ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8119: Mình là nữ đang tìm trọ ạ. Có bạn nào cần ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Xử lý hoàn tất [['8119: Mình là nữ đang tìm trọ ạ. Có bạn nào cần ...] - Tìm thấy: []
#
# Xử lý 33/2641: ['8120: TÌM NGƯỜI Ở GHÉP TRỌ GẦN CS1, chỉ cách trường 300m khoảng 3 phút đi bộ thôi ạ Giá trọ 3tr5, ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8120: TÌM NGƯỜI Ở GHÉP TRỌ GẦN CS1, chỉ cách trư... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# Xử lý hoàn tất [['8120: TÌM NGƯỜI Ở GHÉP TRỌ GẦN CS1, chỉ cách trư...] - Tìm thấy: []
#
# Xử lý 34/2641: ['8115: các em đừng vào cái trường quần què này nha=)) nhiều cái bực hết cả mình ra']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8115: các em đừng vào cái trường quần què này nh... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Xử lý hoàn tất [['8115: các em đừng vào cái trường quần què này nh...] - Tìm thấy: []
#
# Xử lý 35/2641: ['8116: Thật sự là ad nên ghim hẳn cái hastag #hmnufeedback cho các em dễ tìm, cân nhắc kĩ càng khi ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8116: Thật sự là ad nên ghim hẳn cái hastag #hmn... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Xử lý hoàn tất [['8116: Thật sự là ad nên ghim hẳn cái hastag #hmn...] - Tìm thấy: []
#
# Xử lý 36/2641: ['8114: thật sự em muốn một review công tâm về ngành giáo dục tiểu học của trường ạ, với csvc trường...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8114: thật sự em muốn một review công tâm về ngà... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Xử lý hoàn tất [['8114: thật sự em muốn một review công tâm về ngà...] - Tìm thấy: []
#
# Xử lý 37/2641: ['8108: Dạ hi mng. Mng ơi cho mình hỏi là mình muốn xin giấy xác nhận đang theo học tại Trường. Yêu ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8108: Dạ hi mng. Mng ơi cho mình hỏi là mình muố... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Xử lý hoàn tất [['8108: Dạ hi mng. Mng ơi cho mình hỏi là mình muố...] - Tìm thấy: []
#
# Xử lý 38/2641: ['8109: ad ơi bao giờ thì sinh viên được nhận trợ cấp ạ, em mòn mỏi lắm rồi']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8109: ad ơi bao giờ thì sinh viên được nhận trợ ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Xử lý hoàn tất [['8109: ad ơi bao giờ thì sinh viên được nhận trợ ...] - Tìm thấy: []
#
# Xử lý 39/2641: ['8110: Mn ơi thường thì sau ngày tổ chức thi lại bao lâu là có điểm phúc khảo ạ? Sao mãi trường chư...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8110: Mn ơi thường thì sau ngày tổ chức thi lại ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
# Xử lý hoàn tất [['8110: Mn ơi thường thì sau ngày tổ chức thi lại ...] - Tìm thấy: []
#
# Xử lý 40/2641: ['8111: Mn cho tớ hỏi tuần sau tớ lên học ghép thể chất tại sóc sơn ấy, thì k biết trên đấy có cho s...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8111: Mn cho tớ hỏi tuần sau tớ lên học ghép thể... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Xử lý hoàn tất [['8111: Mn cho tớ hỏi tuần sau tớ lên học ghép thể...] - Tìm thấy: []
#
# Xử lý 41/2641: ['8112: Add ơi cho mình hỏi môn lịch sử Đảng thi tự luận hay làm bài tập lớn nhỉ. Mik muốn học cải t...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8112: Add ơi cho mình hỏi môn lịch sử Đảng thi t... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Xử lý hoàn tất [['8112: Add ơi cho mình hỏi môn lịch sử Đảng thi t...] - Tìm thấy: []
#
# Xử lý 42/2641: ['8113: Khi nào thì biết điểm phúc khảo thế ạ ___________________ 8112 lâu quá nên mình cũng quên rồ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8113: Khi nào thì biết điểm phúc khảo thế ạ ____... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Xử lý hoàn tất [['8113: Khi nào thì biết điểm phúc khảo thế ạ ____...] - Tìm thấy: []
#
# Xử lý 43/2641: ['8102: Sư phạm anh sắp tới có xét song bằng k ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8102: Sư phạm anh sắp tới có xét song bằng k ạ']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Xử lý hoàn tất [['8102: Sư phạm anh sắp tới có xét song bằng k ạ']...] - Tìm thấy: []
#
# Xử lý 44/2641: ['8103: Ad cho em hỏi cách đăng ký học song ngành giáo dục tiểu học ntn vậy ạ. Và khi học song ngành...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8103: Ad cho em hỏi cách đăng ký học song ngành ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
# Xử lý hoàn tất [['8103: Ad cho em hỏi cách đăng ký học song ngành ...] - Tìm thấy: []
#
# Xử lý 45/2641: ['8104: cho em hỏi, trong năm học tới đây ngành sư phạm tiếng anh của trường mình có mở văn bằng 2 k...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8104: cho em hỏi, trong năm học tới đây ngành sư... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Xử lý hoàn tất [['8104: cho em hỏi, trong năm học tới đây ngành sư...] - Tìm thấy: []
#
# Xử lý 46/2641: ['8105: ac chone hỏi muốn làm vé tháng xe bus thì phải xin dấu ở đâu ạ?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8105: ac chone hỏi muốn làm vé tháng xe bus thì ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Xử lý hoàn tất [['8105: ac chone hỏi muốn làm vé tháng xe bus thì ...] - Tìm thấy: []
#
# Xử lý 47/2641: ['8106: bao giờ có dsach hb v ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8106: bao giờ có dsach hb v ạ']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Xử lý hoàn tất [['8106: bao giờ có dsach hb v ạ']...] - Tìm thấy: []
#
# Xử lý 48/2641: ['8107: Kí nđ 116 ở đou v ạ ___________________ 8105 ở "phòng quản lí đào tạo & công tác hssv" nhé #...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8107: Kí nđ 116 ở đou v ạ ___________________ 81... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Xử lý hoàn tất [['8107: Kí nđ 116 ở đou v ạ ___________________ 81...] - Tìm thấy: []
#
# Xử lý 49/2641: ['"Dạ ngày 16/7 khoảng tầm 12h trưa e chẳng may làm rơi chiếc ví nhỏ màu xanh bên trong có CCCD và g...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['"Dạ ngày 16/7 khoảng tầm 12h trưa e chẳng may là... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 30
# }
# ]
# Xử lý hoàn tất [['"Dạ ngày 16/7 khoảng tầm 12h trưa e chẳng may là...] - Tìm thấy: []
#
# Xử lý 50/2641: ['8101: ĐKN thiếu hơi trai tc ah ?!? Nta về r còn đăng nhớ a này a kia ___________________ #hnmuvar ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8101: ĐKN thiếu hơi trai tc ah ?!? Nta về r còn ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Xử lý hoàn tất [['8101: ĐKN thiếu hơi trai tc ah ?!? Nta về r còn ...] - Tìm thấy: []
#
# Xử lý 51/2641: ['8100: Mình cần pass giáo trình môn chung và môn riêng cho các b ngành NNA ah ___________________ #...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8100: Mình cần pass giáo trình môn chung và môn ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Xử lý hoàn tất [['8100: Mình cần pass giáo trình môn chung và môn ...] - Tìm thấy: []
#
# Xử lý 52/2641: ['8099: Anh Bách cntt23 ơi, không biết là anh đã có người thương chưa ạ. Em muốn mở lời nói chuyện v...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8099: Anh Bách cntt23 ơi, không biết là anh đã c... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Xử lý hoàn tất [['8099: Anh Bách cntt23 ơi, không biết là anh đã c...] - Tìm thấy: []
#
# Xử lý 53/2641: ['8089: Dạ cho em hỏi trường có ktx không ạ? Nếu có thì có dễ xin không ạ?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8089: Dạ cho em hỏi trường có ktx không ạ? Nếu c... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Xử lý hoàn tất [['8089: Dạ cho em hỏi trường có ktx không ạ? Nếu c...] - Tìm thấy: []
#
# Xử lý 54/2641: ['8090: Trường mình có thi tiếng anh đầu vào và ra không ạ ?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8090: Trường mình có thi tiếng anh đầu vào và ra... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Xử lý hoàn tất [['8090: Trường mình có thi tiếng anh đầu vào và ra...] - Tìm thấy: []
#
# Xử lý 55/2641: ['8092: Mn oi lên trg kí nđ116 tại khoa đào tạo là ở cơ sở mấy vs phòng nào thế ạ hay vx đợi lớp tb ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8092: Mn oi lên trg kí nđ116 tại khoa đào tạo là... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Xử lý hoàn tất [['8092: Mn oi lên trg kí nđ116 tại khoa đào tạo là...] - Tìm thấy: []
#
# Xử lý 56/2641: ['8093: Ad ơi khoảng bao giờ thì k24 đk tín cho kì 3 ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8093: Ad ơi khoảng bao giờ thì k24 đk tín cho kì... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Xử lý hoàn tất [['8093: Ad ơi khoảng bao giờ thì k24 đk tín cho kì...] - Tìm thấy: []
#
# Xử lý 57/2641: ['8094: ad ơi ra trg bắt buộc ph có cc tin học và ngoại ngữ đúng k ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8094: ad ơi ra trg bắt buộc ph có cc tin học và ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Xử lý hoàn tất [['8094: ad ơi ra trg bắt buộc ph có cc tin học và ...] - Tìm thấy: []
#
# Xử lý 58/2641: ['8095: Mọi người cho em hỏi với ạ. Đợt đầu năm học 2024 sinh viên trường mình cuối cùng có được bên...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8095: Mọi người cho em hỏi với ạ. Đợt đầu năm họ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Xử lý hoàn tất [['8095: Mọi người cho em hỏi với ạ. Đợt đầu năm họ...] - Tìm thấy: []
#
# Xử lý 59/2641: ['8096: Cho em xin thông tin trường mình thay đổi chứng chỉ tiếng anh với ạ. Nghe các bạn k24 nói kh...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8096: Cho em xin thông tin trường mình thay đổi ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Xử lý hoàn tất [['8096: Cho em xin thông tin trường mình thay đổi ...] - Tìm thấy: []
#
# Xử lý 60/2641: ['8098: Kí xác nhận bao lâu thì nhận được trợ cấp mọi người nhỉ? ___________________ 8090 có']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8098: Kí xác nhận bao lâu thì nhận được trợ cấp ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Xử lý hoàn tất [['8098: Kí xác nhận bao lâu thì nhận được trợ cấp ...] - Tìm thấy: []
#
# Xử lý 61/2641: ['8093 học kì 3 là học kì phụ đó, còn học kì 1 năm tới sẽ vào tháng 8 nhé. Bạn xem lịch trình năm họ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8093 học kì 3 là học kì phụ đó, còn học kì 1 năm... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# Xử lý hoàn tất [['8093 học kì 3 là học kì phụ đó, còn học kì 1 năm...] - Tìm thấy: []
#
# Xử lý 62/2641: ['8084 đúng #hnmuhoidap #hnmucfs']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8084 đúng #hnmuhoidap #hnmucfs']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Xử lý hoàn tất [['8084 đúng #hnmuhoidap #hnmucfs']...] - Tìm thấy: []
#
# Xử lý 63/2641: ['8091: E thấy trường bảo đang làm truyền thông mạnh lắm mà sao lướt mấy bài về các trường đhoc như ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8091: E thấy trường bảo đang làm truyền thông mạ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Xử lý hoàn tất [['8091: E thấy trường bảo đang làm truyền thông mạ...] - Tìm thấy: []
#
# Xử lý 64/2641: ['8097: Xin chào admin, chào các bạn. Tớ là D21, sắp tới tốt nghiệp. Không biết ad hay có anh chị nà...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8097: Xin chào admin, chào các bạn. Tớ là D21, s... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Xử lý hoàn tất [['8097: Xin chào admin, chào các bạn. Tớ là D21, s...] - Tìm thấy: []
#
# Xử lý 65/2641: ['8088: Các em đừng có vào cái trường này. Bực hết cả mình. Mỗi cái chứng chỉ tiếng anh mà thay đổi ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8088: Các em đừng có vào cái trường này. Bực hết... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Xử lý hoàn tất [['8088: Các em đừng có vào cái trường này. Bực hết...] - Tìm thấy: []
#
# Xử lý 66/2641: ['8086: Bạn P tđ1 lớp GDTC có ngyeu/ crush chưa ạ ___________________ #hnmutimny #hnmucfs']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# ...
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Xử lý hoàn tất [['8042: Trường mình có ac hay bạn nào đã học toeic...] - Tìm thấy: []
#
# Xử lý 113/2641: ['8040: nhiều bạn buồn cười nhỉ có đi hoạt động mấy đâu rồi tự nghĩ mình đrl được cao lúc cbl chấm l...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8040: nhiều bạn buồn cười nhỉ có đi hoạt động mấ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Xử lý hoàn tất [['8040: nhiều bạn buồn cười nhỉ có đi hoạt động mấ...] - Tìm thấy: []
#
# Xử lý 114/2641: ['8039: Ac ai học nna thì cho em xin chút rv về môn kĩ năng tt tiếng anh và giao tiếp giao văn hoá v...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8039: Ac ai học nna thì cho em xin chút rv về mô... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Xử lý hoàn tất [['8039: Ac ai học nna thì cho em xin chút rv về mô...] - Tìm thấy: []
#
# Xử lý 115/2641: ['8037: Mình xin info bạn Đức Anh Trung đội 6 với ạ. Mình thích bạn nhưng ngại ấy __________________...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8037: Mình xin info bạn Đức Anh Trung đội 6 với ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Xử lý hoàn tất [['8037: Mình xin info bạn Đức Anh Trung đội 6 với ...] - Tìm thấy: []
#
# Xử lý 116/2641: ['8036: giữa tháng 7 luôn rồi vẫn chưa thấy ho he gì trợ cấp, trường định bao giờ mới trả cho sinh v...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8036: giữa tháng 7 luôn rồi vẫn chưa thấy ho he ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Xử lý hoàn tất [['8036: giữa tháng 7 luôn rồi vẫn chưa thấy ho he ...] - Tìm thấy: []
#
# Xử lý 117/2641: ['8038: Trường trả trợ cấp cho sinh viên đi ạ. Chúng em cx cần đến tiền lắm ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8038: Trường trả trợ cấp cho sinh viên đi ạ. Chú... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Xử lý hoàn tất [['8038: Trường trả trợ cấp cho sinh viên đi ạ. Chú...] - Tìm thấy: []
#
# Xử lý 118/2641: ['8033: Tìm bạn nam ở cùng gần cơ sở 3 ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8033: Tìm bạn nam ở cùng gần cơ sở 3 ạ']... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Xử lý hoàn tất [['8033: Tìm bạn nam ở cùng gần cơ sở 3 ạ']...] - Tìm thấy: []
#
# Xử lý 119/2641: ['8034: Phòng 3tr3 (chưa chia) cách cs1 khoảng 300m. Phòng có gác lửng, bạn nào có nhu cầu trọ cùng ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8034: Phòng 3tr3 (chưa chia) cách cs1 khoảng 300... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ]
# Xử lý hoàn tất [['8034: Phòng 3tr3 (chưa chia) cách cs1 khoảng 300...] - Tìm thấy: []
#
# Xử lý 120/2641: ['8035: Ai có trọ gần trường mà ổn áp không, tc 3 triệu, sạch, bình thường. Em cần chuyển trọ gấp ,h...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8035: Ai có trọ gần trường mà ổn áp không, tc 3 ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Xử lý hoàn tất [['8035: Ai có trọ gần trường mà ổn áp không, tc 3 ...] - Tìm thấy: []
#
# Xử lý 121/2641: ['E để cccd chỗ phòng bảo vệ mà giờ thất lạc ai cầm nhầm #hnmusos']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['E để cccd chỗ phòng bảo vệ mà giờ thất lạc ai cầ... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Xử lý hoàn tất [['E để cccd chỗ phòng bảo vệ mà giờ thất lạc ai cầ...] - Tìm thấy: []
#
# Xử lý 122/2641: ['8030: Cho e hỏi là mình có được đổi môn thể chất khác với môn mình đăng kí ko ạ ?']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8030: Cho e hỏi là mình có được đổi môn thể chất... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Xử lý hoàn tất [['8030: Cho e hỏi là mình có được đổi môn thể chất...] - Tìm thấy: []
#
# Xử lý 123/2641: ['8031: Bọn mình có 3 người đang cần tìm thêm 1 người nữa ở cùng để thuê căn rộng rãi , thoải mái, đ...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8031: Bọn mình có 3 người đang cần tìm thêm 1 ng... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Xử lý hoàn tất [['8031: Bọn mình có 3 người đang cần tìm thêm 1 ng...] - Tìm thấy: []
#
# Xử lý 124/2641: ['8032: Anh chị cho em hỏi với ạaa có ai đã học đá cầu thầy Đỗ Hữu Trung và thầy Nguyễn Duy Linh chư...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8032: Anh chị cho em hỏi với ạaa có ai đã học đá... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Xử lý hoàn tất [['8032: Anh chị cho em hỏi với ạaa có ai đã học đá...] - Tìm thấy: []
#
# Xử lý 125/2641: ['8029: nhớ các bạn gdtc của tôi quá điiii nhớ các b ở phòng nghỉ gv nữ ___________________ #hnmutam...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# Lỗi trong lần thử 3, thử lại...
# Lỗi trong lần thử 4, thử lại...
# Lỗi khi gọi API cho văn bản: ['8029: nhớ các bạn gdtc của tôi quá điiii nhớ các... - 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 5
# }
# ]
# Xử lý hoàn tất [['8029: nhớ các bạn gdtc của tôi quá điiii nhớ các...] - Tìm thấy: []
#
# Xử lý 126/2641: ['7748: ở khu qsu vòi nước lắp đầu lọc tròn hay vuông ạ']...
# Lỗi trong lần thử 1, thử lại...
# Lỗi trong lần thử 2, thử lại...
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[10], line 15, in detect_abbreviations(text)
#      10 prompt = f"""
#      11 Phân tích văn bản tiếng Việt sau và liệt kê các từ viết tắt hoặc ký hiệu không rõ ràng về ngữ nghĩa (ví dụ: từ rút gọn, viết tắt phổ biến như 'ad', 'ib', 'tt', 'rep', ...).
#      12 Chỉ trả về danh sách các từ viết tắt, không giải thích. Nếu không có từ viết tắt, trả về danh sách rỗng.
#      13 Văn bản: {text}
#      14 """
# ---> 15 response = model.generate_content(prompt)
#      16 abbreviations = response.text.strip().split("\n")
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330 else:
# --> 331     response = self._client.generate_content(
#     332         request,
#     333         **request_options,
#     334     )
#     335     return generation_types.GenerateContentResponse.from_response(response)
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File c:\Users\nguye\.conda\envs\myenv\lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      13 print(f"Bắt đầu xử lý file: {input_file}")
#      14 print(f"Kết quả sẽ được lưu vào: {output_file}")
# ---> 16 process_json_file(input_file, output_file)
#
# Cell In[11], line 27, in process_json_file(input_file, output_file)
#      24 print(f"\nXử lý {idx}/{total_posts}: {post_text[:100]}...")
#      26 # Tìm từ viết tắt
# ---> 27 abbreviations = detect_abbreviations(post_text)
#      28 print(f"Xử lý hoàn tất [{post_text[:50]}...] - Tìm thấy: {abbreviations}")
#      30 # Tạo kết quả cho post
#
# Cell In[10], line 24, in detect_abbreviations(text)
#      22 if attempt < max_retries - 1:
#      23     print(f"Lỗi trong lần thử {attempt + 1}, thử lại...")
# ---> 24     time.sleep(5)
#      25 else:
#      26     print(f"Lỗi khi gọi API cho văn bản: {text[:50]}... - {e}")
#
# KeyboardInterrupt:
